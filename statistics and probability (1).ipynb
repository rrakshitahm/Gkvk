# %%
import numpy as np
scores=[10,12,15,100]
print(np.mean(scores))
# Out:
# 34.25

# %%
import numpy as np
cricket_score=[10,12,15,100]
median_score=np.median(cricket_score)
print(f"median:{median_score}")
# Out:
# median:13.5

# %%
import numpy as np
quiz_score=[2,18,17,19]
median_score=np.median(quiz_score)
print(f"median:{median_score}")
# Out:
# median:17.5

# %%
from statistics import mode
votes=[1,2,3,2,4]
most_common=mode(votes)
print(most_common)
# Out:
# 2

# %%
from statistics import mode
numbers=[1,2,3,3,4,5,6,7,8,9,9,9,10]
most_common=mode(numbers)
print(most_common)
# Out:
# 9

# %%
import numpy as np
tight_data=[60,70,80]
spread_data=[20,70,80]
print("tight std:",np.std(tight_data))
print("spread std:",np.std(spread_data))
# Out:
# tight std: 8.16496580927726
# spread std: 26.246692913372705

# %%
import random
#simulating random predictions
for i in range(3):
    prediction=random.choice(["spam","not spam"])
    print(f"email.{i+1}:{prediction}")
# Out:
# email.1:spam
# email.2:not spam
# email.3:not spam

# %%
import random
#simulate 10 dice rolls
sample=[random.randint(1,6) for _ in range(10)]
print("sample rolls:",sample)
print("sample mean:",sum (sample)/len(sample))
# Out:
# sample rolls: [1, 4, 3, 3, 4, 3, 2, 4, 5, 4]
# sample mean: 3.3
