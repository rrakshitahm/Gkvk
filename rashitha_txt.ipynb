# %%
name= "rakshitha"
print(len(name))

file=open("/Untitled5.txt","r")
content=file.read()
print(content)
file.close()
# Out:
# 9
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2367518932.py in <cell line: 0>()
#       2 print(len(name))
#       3
# ----> 4 file=open("/Untitled5.txt","r")
#       5 content=file.read()
#       6 print(content)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Untitled5.txt'

# %%
from google.colab import drive
drive.mount('/content/drive')
